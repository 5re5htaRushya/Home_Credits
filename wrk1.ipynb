# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('C:/Users/ZMHD022/Desktop/HC/home-credit-default-risk/corelation.csv')

# %%
df1 = df.drop('id',axis=1)

# %%
df1.corr()
# Out:
#                    target  total_income    cr_amt  annuity_amt  \
# target           1.000000     -0.003982 -0.030369    -0.012817
# total_income    -0.003982      1.000000  0.156870     0.191657
# cr_amt          -0.030369      0.156870  1.000000     0.770138
# annuity_amt     -0.012817      0.191657  0.770138     1.000000
# goods_price_amt -0.039645      0.159610  0.986968     0.775109
#
#                  goods_price_amt
# target                 -0.039645
# total_income            0.159610
# cr_amt                  0.986968
# annuity_amt             0.775109
# goods_price_amt         1.000000

# %%
df1.describe().transpose()
# Out:
#                     count           mean            std      min       25%  \
# target           307511.0       0.080729       0.272419      0.0       0.0
# total_income     307511.0  168797.919297  237123.146279  25650.0  112500.0
# cr_amt           307511.0  599025.999706  402490.776996  45000.0  270000.0
# annuity_amt      307499.0   27108.573909   14493.737315   1615.5   16524.0
# goods_price_amt  307233.0  538396.207429  369446.460540  40500.0  238500.0
#
#                       50%       75%          max
# target                0.0       0.0          1.0
# total_income     147150.0  202500.0  117000000.0
# cr_amt           513531.0  808650.0    4050000.0
# annuity_amt       24903.0   34596.0     258025.5
# goods_price_amt  450000.0  679500.0    4050000.0

# %%
df2 = pd.read_csv('C:/Users/ZMHD022/Desktop/HC/home-credit-default-risk/predict_score.csv')

# %%
df3 = df2.drop('id',axis=1)

# %%
df3.describe().transpose()
# Out:
#            count      mean       std           min       25%       50%  \
# target  307511.0  0.080729  0.272419  0.000000e+00  0.000000  0.000000
# score1  134133.0  0.502130  0.211062  1.456813e-02  0.334007  0.505998
# score2  306851.0  0.514393  0.191060  8.170000e-08  0.392457  0.565961
# score3  246546.0  0.510853  0.194844  5.272650e-04  0.370650  0.535276
#
#              75%       max
# target  0.000000  1.000000
# score1  0.675053  0.962693
# score2  0.663617  0.855000
# score3  0.669057  0.896010

# %%
df3.corr()
# Out:
#           target    score1    score2    score3
# target  1.000000 -0.155317 -0.160472 -0.178919
# score1 -0.155317  1.000000  0.213982  0.186846
# score2 -0.160472  0.213982  1.000000  0.109167
# score3 -0.178919  0.186846  0.109167  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df4 = pd.read_csv('C:/Users/ZMHD022/Desktop/HC/home-credit-default-risk/distribution.csv')

# %%
df5.head()
# Out:
#    target  total_income     cr_amt  annuity_amt  goods_price_amt gender  \
# 0       1      202500.0   406597.5      24700.5         351000.0      M
# 1       0      270000.0  1293502.5      35698.5        1129500.0      F
# 2       0       67500.0   135000.0       6750.0         135000.0      M
# 3       0      135000.0   312682.5      29686.5         297000.0      F
# 4       0      121500.0   513000.0      21865.5         513000.0      M
#
#   own_car own_house    income_type                       edu_type
# 0       N         Y        Working  Secondary / secondary special
# 1       N         N  State servant               Higher education
# 2       Y         Y        Working  Secondary / secondary special
# 3       N         Y        Working  Secondary / secondary special
# 4       N         Y        Working  Secondary / secondary special

# %%
sns.countplot(x='gender', data=df5);
plt.title('Distribution of Gender');

# %%
plt.hist(df5['total_income'], data=df5[df5['gender'] == 'M'], label='M');
plt.hist(df5['total_income'], data=df5[df5['gender'] == 'F'], label='F');
plt.title('Distribution of Income by Gender');
plt.legend();

# %%
pd.crosstab(df5['target'], df5['gender'])
# Out:
# gender       F      M  XNA
# target
# 0       188278  94404    4
# 1        14170  10655    0

# %%
pd.crosstab(df5['target'], df5['own_car'])
# Out:
# own_car       N      Y
# target
# 0        185675  97011
# 1         17249   7576

# %%
pd.crosstab(df5['target'], df5['own_house'])
# Out:
# own_house      N       Y
# target
# 0          86357  196329
# 1           7842   16983

# %%
pd.crosstab(df5['target'], df5['income_type'])
# Out:
# income_type  Businessman  Commercial associate  Maternity leave  Pensioner  \
# target
# 0                     10                 66257                3      52380
# 1                      0                  5360                2       2982
#
# income_type  State servant  Student  Unemployed  Working
# target
# 0                    20454       18          14   143550
# 1                     1249        0           8    15224

# %%
pd.crosstab(df5['target'], df5['edu_type'])
# Out:
# edu_type  Academic degree  Higher education  Incomplete higher  \
# target
# 0                     161             70854               9405
# 1                       3              4009                872
#
# edu_type  Lower secondary  Secondary / secondary special
# target
# 0                    3399                         198867
# 1                     417                          19524

# %%
pd.crosstab(df5['total_income'], df5['gender'])
# Out:
# gender          F   M  XNA
# total_income
# 25650.0         2   0    0
# 26100.0         3   0    0
# 26460.0         1   0    0
# 26550.0         2   0    0
# 27000.0        58   8    0
# 27585.0         1   0    0
# 27900.0         7   0    0
# 27967.5         1   0    0
# 28161.0         0   1    0
# 28350.0         8   3    0
# 28404.0         1   0    0
# 28575.0         3   0    0
# 28593.0         1   0    0
# 28723.5         1   0    0
# 28800.0         3   0    0
# 29133.0         1   0    0
# 29250.0        25   7    0
# 29583.0         1   0    0
# 29700.0         3   0    0
# 30150.0         6   1    0
# 30600.0         5   1    0
# 30915.0         1   0    0
# 31050.0         1   0    0
# 31500.0       170  14    0
# 31531.5         1   0    0
# 31815.0         1   0    0
# 31860.0         0   1    0
# 31950.0         4   0    0
# 31990.5         1   0    0
# 32040.0         1   0    0
# ...           ...  ..  ...
# 1358550.0       1   0    0
# ...

# %%
df5['total_income'].max()
# Out:
# 117000000.0

# %%
df5['total_income'].min()
# Out:
# 25650.0
