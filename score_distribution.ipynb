# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('C:/Users/ZMHD022/Desktop/HC/home-credit-default-risk/scores.csv')

# %%
df.describe()
# Out:
#                   ID         TARGET         SCORE1             S1  \
# count  307511.000000  307511.000000  134133.000000  307511.000000
# mean   278180.518577       0.080729       0.502130      21.902364
# std    102790.175348       0.272419       0.211062      28.537362
# min    100002.000000       0.000000       0.014568       0.000000
# 25%    189145.500000       0.000000       0.334007       0.000000
# 50%    278202.000000       0.000000       0.505998       0.000000
# 75%    367142.500000       0.000000       0.675053      45.626098
# max    456255.000000       1.000000       0.962693      96.269277
#
#              SCORE2             S2         SCORE3             S3
# count  3.068510e+05  307511.000000  246546.000000  307511.000000
# mean   5.143927e-01      51.328865       0.510853      40.957475
# std    1.910602e-01      19.233388       0.194844      26.817693
# min    8.170000e-08       0.000000       0.000527       0.000000
# ...

# %%
df['SCORE1'].min()
# Out:
# 0.014568132

# %%
df['SCORE1'].max()
# Out:
# 0.962692771

# %%
df['SCORE2'].min()
# Out:
# 8.17e-08

# %%
df['SCORE2'].max()
# Out:
# 0.854999666

# %%
df['SCORE3'].min()
# Out:
# 0.000527265

# %%
df['SCORE3'].max()
# Out:
# 0.8960095490000001

# %%
 from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
# Out:
# C:\Users\ZMHD022\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
df_scaled
# Out:
#               ID  TARGET    SCORE1        S1    SCORE2        S2    SCORE3  \
# 0       0.000000     1.0  0.072215  0.086255  0.307542  0.307542  0.155054
# 1       0.000003     0.0  0.312933  0.323330  0.727773  0.727773       NaN
# 2       0.000006     0.0       NaN  0.000000  0.650190  0.650190  0.814130
# 3       0.000011     0.0       NaN  0.000000  0.760751  0.760751       NaN
# 4       0.000014     0.0       NaN  0.000000  0.377472  0.377472       NaN
# 5       0.000017     0.0       NaN  0.000000  0.414298  0.414298  0.693145
# 6       0.000020     0.0  0.801786  0.804786  0.846784  0.846784  0.548903
# 7       0.000022     0.0       NaN  0.000000  0.835415  0.835415  0.603169
# 8       0.000025     0.0  0.604104  0.610095  0.240640  0.240640  0.838874
# 9       0.000028     0.0       NaN  0.000000  0.873268  0.873268       NaN
# 10      0.000034     0.0  0.321890  0.332152  0.762412  0.762412  0.405835
# ...

# %%
df_scaled['SCORE1']*100
# Out:
# 0          7.221501
# 1         31.293267
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6         80.178623
# 7               NaN
# 8         60.410403
# 9               NaN
# 10        32.189021
# 11        74.618493
# 12        47.489852
# 13              NaN
# 14        74.607452
# 15        10.659591
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20        58.123872
# 21        44.629247
# 22              NaN
# 23              NaN
# 24              NaN
# 25        57.732945
# 26              NaN
# 27              NaN
# 28        61.788055
# 29        29.884824
#             ...
# 307481          NaN
# 307482    48.120264
# 307483          NaN
# 307484          NaN
# 307485    43.435559
# 307486          NaN
# 307487          NaN
# 307488    49.032580
# 307489          NaN
# 307490    24.369680
# 307491    54.664768
# 307492          NaN
# 307493          NaN
# 307494    54.571000
# ...

# %%
df_scaled['SCORE2']*100
# Out:
# 0         30.754227
# 1         72.777309
# 2         65.018979
# 3         76.075079
# 4         37.747177
# 5         41.429804
# 6         84.678377
# 7         83.541468
# 8         24.064012
# 9         87.326773
# 10        76.241236
# 11        64.933725
# 12        83.630653
# 13        66.304890
# 14        75.164495
# 15        40.541996
# 16        27.646535
# 17        79.943111
# 18        82.623236
# 19        68.610216
# 20        13.260174
# 21        27.341168
# 22        53.467031
# 23        73.018124
# 24        91.950832
# 25        76.187821
# 26        64.149397
# 27        63.289343
# 28        80.118274
# 29        58.804585
#             ...
# 307481    83.453186
# 307482    86.304744
# 307483    68.994911
# 307484    86.514996
# 307485    82.152484
# 307486    77.312895
# 307487    35.916089
# 307488    72.475114
# 307489    71.960412
# 307490    44.259786
# 307491    65.632586
# 307492    70.078758
# 307493    49.670486
# 307494    81.839458
# ...

# %%
df_scaled['SCORE3']*100
# Out:
# 0         15.505445
# 1               NaN
# 2         81.413048
# 3               NaN
# 4               NaN
# 5         69.314501
# 6         54.890291
# 7         60.316903
# 8         83.887360
# 9               NaN
# 10        40.583491
# 11        72.851166
# 12        19.668208
# 13        85.938027
# 14              NaN
# 15        75.717905
# 16         6.876269
# 17              NaN
# 18        62.111800
# 19        53.280997
# 20              NaN
# 21        60.516873
# 22        40.025802
# 23        74.655796
# 24        63.103506
# 25        51.475628
# 26        21.237571
# 27        73.578035
# 28        58.512512
# 29              NaN
#             ...
# 307481    57.104931
# 307482    43.995079
# 307483    58.110623
# 307484          NaN
# 307485    96.637160
# 307486    22.249832
# 307487    28.454444
# 307488    59.114801
# 307489    44.380449
# 307490    55.292949
# 307491    79.961714
# 307492    40.770124
# 307493    81.253873
# 307494    57.104931
# ...

# %%
df_scaled
# Out:
#               ID  TARGET    SCORE1        S1    SCORE2        S2    SCORE3  \
# 0       0.000000     1.0  0.072215  0.086255  0.307542  0.307542  0.155054
# 1       0.000003     0.0  0.312933  0.323330  0.727773  0.727773       NaN
# 2       0.000006     0.0       NaN  0.000000  0.650190  0.650190  0.814130
# 3       0.000011     0.0       NaN  0.000000  0.760751  0.760751       NaN
# 4       0.000014     0.0       NaN  0.000000  0.377472  0.377472       NaN
# 5       0.000017     0.0       NaN  0.000000  0.414298  0.414298  0.693145
# 6       0.000020     0.0  0.801786  0.804786  0.846784  0.846784  0.548903
# 7       0.000022     0.0       NaN  0.000000  0.835415  0.835415  0.603169
# 8       0.000025     0.0  0.604104  0.610095  0.240640  0.240640  0.838874
# 9       0.000028     0.0       NaN  0.000000  0.873268  0.873268       NaN
# 10      0.000034     0.0  0.321890  0.332152  0.762412  0.762412  0.405835
# ...

# %%
df_scaled.to_csv('C:/Users/ZMHD022/Desktop/HC/home-credit-default-risk/s.csv')

# %%
df2= pd.read_csv('C:/Users/ZMHD022/Desktop/HC/home-credit-default-risk/s.csv')

# %%
from matplotlib.pyplot import hist

# %%
df.plot( x='ID', y='S1', kind='hist')

# %%
df.plot( x='ID', y='S2', kind='hist')

# %%
df.plot( x='ID', y='S3', kind='hist')

# %%
df.plot( x='S1', y='TARGET', kind='hist')

# %%
df.plot( x='S2', y='TARGET', kind='hist')

# %%
df.plot( x='S3', y='TARGET', kind='hist')

# %%
df.plot( x='S1', y='TARGET', kind='')
